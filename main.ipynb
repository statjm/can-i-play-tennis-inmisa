# %%
source("misa_hyena.R")

# %%
system.time(res <- misa_hyena("202202",golden_time = T))
# Out:
#    user  system elapsed
#   0.504   0.001   2.026

# %%
res
# Out:
#    일자       요일 이용시간      1코트 2코트 3코트 4코트
# 1  2022-02-01 화   18:00 ~ 20:00
# 2  2022-02-01 화   20:00 ~ 22:00
# 3  2022-02-02 수   18:00 ~ 20:00
# 4  2022-02-02 수   20:00 ~ 22:00
# 5  2022-02-03 목   18:00 ~ 20:00
# 6  2022-02-03 목   20:00 ~ 22:00
# 7  2022-02-06 일   18:00 ~ 20:00
# 8  2022-02-06 일   20:00 ~ 22:00
# 9  2022-02-07 월   18:00 ~ 20:00
# 10 2022-02-07 월   20:00 ~ 22:00
# 11 2022-02-08 화   18:00 ~ 20:00
# 12 2022-02-08 화   20:00 ~ 22:00
# 13 2022-02-09 수   18:00 ~ 20:00
# 14 2022-02-09 수   20:00 ~ 22:00
# 15 2022-02-10 목   18:00 ~ 20:00
# 16 2022-02-10 목   20:00 ~ 22:00
# 17 2022-02-13 일   18:00 ~ 20:00
# 18 2022-02-13 일   20:00 ~ 22:00
# 19 2022-02-14 월   18:00 ~ 20:00
# 20 2022-02-14 월   20:00 ~ 22:00
# 21 2022-02-15 화   18:00 ~ 20:00
# 22 2022-02-15 화   20:00 ~ 22:00
# 23 2022-02-16 수   18:00 ~ 20:00
# 24 2022-02-16 수   20:00 ~ 22:00
# 25 2022-02-17 목   18:00 ~ 20:00
# 26 2022-02-17 목   20:00 ~ 22:00
# 27 2022-02-20 일   18:00 ~ 20:00
# 28 2022-02-20 일   20:00 ~ 22:00
# ...
