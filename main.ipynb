# %%
source("misa_hyena.R")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.1     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter()         masks stats::filter()
# ✖ readr::guess_encoding() masks rvest::guess_encoding()
# ✖ dplyr::lag()            masks stats::lag()

# %%
system.time(res <- misa_hyena("202202",golden_time = F))
# Out:
#    user  system elapsed
#   0.303   0.009   1.923

# %%
res
# Out:
#     일자       요일 이용시간      1코트    2코트    3코트    4코트
# 1   2022-02-01 화   06:00 ~ 08:00
# 2   2022-02-01 화   08:00 ~ 10:00
# 3   2022-02-01 화   10:00 ~ 12:00
# 4   2022-02-02 수   06:00 ~ 08:00
# 5   2022-02-02 수   08:00 ~ 10:00
# 6   2022-02-02 수   10:00 ~ 12:00
# 7   2022-02-03 목   06:00 ~ 08:00
# 8   2022-02-03 목   08:00 ~ 10:00
# 9   2022-02-03 목   10:00 ~ 12:00
# 10  2022-02-04 금   06:00 ~ 08:00
# 11  2022-02-04 금   08:00 ~ 10:00
# 12  2022-02-04 금   10:00 ~ 12:00
# 13  2022-02-05 토   06:00 ~ 08:00
# 14  2022-02-05 토   08:00 ~ 10:00
# 15  2022-02-05 토   10:00 ~ 12:00
# 16  2022-02-06 일   06:00 ~ 08:00
# 17  2022-02-06 일   08:00 ~ 10:00
# 18  2022-02-06 일   10:00 ~ 12:00
# 19  2022-02-07 월   06:00 ~ 08:00
# 20  2022-02-07 월   08:00 ~ 10:00
# 21  2022-02-07 월   10:00 ~ 12:00
# 22  2022-02-08 화   06:00 ~ 08:00
# 23  2022-02-08 화   08:00 ~ 10:00
# 24  2022-02-08 화   10:00 ~ 12:00
# 25  2022-02-08 화   12:00 ~ 14:00
# 26  2022-02-08 화   14:00 ~ 16:00
# 27  2022-02-08 화   16:00 ~ 18:00
# ...
